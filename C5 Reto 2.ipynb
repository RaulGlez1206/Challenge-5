# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
import sklearn
import random
from math import ceil
import random as rd
import copy

# %%
from sklearn.datasets import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
X
# Out:
# array([[ 8.36856841e-01,  2.13635938e+00],
#        [-1.41365810e+00,  7.40962324e+00],
#        [ 1.15521298e+00,  5.09961887e+00],
#        [-1.01861632e+00,  7.81491465e+00],
#        [ 1.27135141e+00,  1.89254207e+00],
#        [ 3.43761754e+00,  2.61654166e-01],
#        [-1.80822253e+00,  1.59701749e+00],
#        [ 1.41372442e+00,  4.38117707e+00],
#        [-2.04932168e-01,  8.43209665e+00],
#        [-7.11099611e-01,  8.66043846e+00],
#        [-1.71237268e+00,  2.77780226e+00],
#        [-2.67000792e+00,  8.35389140e+00],
#        [ 1.24258802e+00,  4.50399192e+00],
#        [-2.22783649e+00,  6.89479938e+00],
#        [ 1.45513831e+00, -2.91989981e-02],
#        [ 4.53791789e-01,  3.95647753e+00],
#        [ 1.06923853e+00,  4.53068484e+00],
#        [ 2.56936589e+00,  5.07048304e-01],
#        [-1.06690610e+00,  3.13165795e+00],
#        [-1.07859101e+00,  2.20451529e+00],
#        [ 2.71506328e+00,  1.29082190e+00],
#        [ 1.77710994e+00,  1.18655254e+00],
# ...

# %%
y_true
# Out:
# array([1, 3, 0, 3, 1, 1, 2, 0, 3, 3, 2, 3, 0, 3, 1, 0, 0, 1, 2, 2, 1, 1,
#        0, 2, 2, 0, 1, 0, 2, 0, 3, 3, 0, 3, 3, 3, 3, 3, 2, 1, 0, 2, 0, 0,
#        2, 2, 3, 2, 3, 1, 2, 1, 3, 1, 1, 2, 3, 2, 3, 1, 3, 0, 3, 2, 2, 2,
#        3, 1, 3, 2, 0, 2, 3, 2, 2, 3, 2, 0, 1, 3, 1, 0, 1, 1, 3, 0, 1, 0,
#        3, 3, 0, 1, 3, 2, 2, 0, 1, 1, 0, 2, 3, 1, 3, 1, 0, 1, 1, 0, 3, 0,
#        2, 2, 1, 3, 1, 0, 3, 1, 1, 0, 2, 1, 2, 1, 1, 1, 1, 2, 1, 2, 3, 2,
#        2, 1, 3, 2, 2, 3, 0, 3, 3, 2, 0, 2, 0, 2, 3, 0, 3, 3, 3, 0, 3, 0,
#        1, 2, 3, 2, 1, 0, 3, 0, 0, 1, 0, 2, 2, 0, 1, 0, 0, 3, 1, 0, 2, 3,
#        1, 1, 0, 2, 1, 0, 2, 2, 0, 0, 0, 0, 1, 3, 0, 2, 0, 0, 2, 2, 2, 0,
#        2, 3, 0, 2, 1, 2, 0, 3, 2, 3, 0, 3, 0, 2, 0, 0, 3, 2, 2, 1, 1, 0,
#        3, 1, 1, 2, 1, 2, 0, 3, 3, 0, 0, 3, 0, 1, 2, 0, 1, 2, 3, 2, 1, 0,
#        1, 3, 3, 3, 3, 2, 2, 3, 0, 2, 1, 0, 2, 2, 2, 1, 1, 3, 0, 0, 2, 1,
#        3, 2, 0, 3, 0, 1, 1, 2, 2, 0, 1, 1, 1, 0, 3, 3, 1, 1, 0, 1, 1, 1,
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
print(y_kmeans)
# Out:
# [2 1 0 1 2 2 3 0 1 1 3 1 0 1 2 0 0 2 3 3 2 2 0 3 3 0 2 0 3 0 1 1 0 1 1 1 1
#  1 3 2 0 3 0 0 3 3 1 3 1 2 3 2 1 2 2 3 1 3 1 2 1 0 1 3 3 3 1 2 1 3 0 3 1 3
#  3 1 3 0 2 1 2 0 2 2 1 0 2 0 1 1 0 2 1 3 3 0 2 2 0 3 1 2 1 2 0 2 2 0 1 0 3
#  3 2 1 2 0 1 2 2 0 3 2 3 2 2 2 2 3 2 3 1 3 3 2 1 3 3 1 0 1 1 3 0 3 0 3 1 0
#  1 1 1 0 1 0 2 3 1 3 2 0 1 0 0 2 0 3 3 0 2 0 0 1 2 0 3 1 2 2 0 3 2 0 3 3 0
#  0 0 0 2 1 0 3 0 0 3 3 3 0 3 1 0 3 2 3 0 1 3 1 0 1 0 3 0 0 1 3 3 2 2 0 1 2
#  2 3 2 3 0 1 1 0 0 1 0 2 3 0 2 3 1 3 2 0 2 1 1 1 1 3 3 1 0 3 2 0 3 3 3 2 2
#  1 0 0 3 2 1 3 0 1 0 2 2 3 3 0 2 2 2 0 1 1 2 2 0 2 2 2 1 3 1 0 2 2 1 1 1 2
#  2 0 1 3]
# c:\Users\RAUL GLEZ\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
def inicia_centroides(x, n_clusters, semilla=2):
    random.seed(2)
    centroids = {i+1 : [random.choices(X)] for i in range(n_clusters)}
    return centroids

# %%
n_clusters = 4
cen = inicia_centroides(X, n_clusters, semilla=2)
for i in cen :
    print(cen[i])
# Out:
# [[array([-1.5587672,  7.2481621])]]
# [[array([2.22322228, 0.83877343])]]
# [[array([1.06923853, 4.53068484])]]
# [[array([-0.55552381,  4.69595848])]]

# %%
plt.scatter(X[:,0],X[:,1],c=y_true,s50,cmap='viridis');
# Out:
#   Cell In[41], line 1
#     plt.scatter(X[:,0],X[:,1],c=y_true,s50,cmap='viridis');
#                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.scatter(X, y_true, color='yellow', alpha=0.5, edgecolor='black')
for i in cen:
    plt.scatter(cen[i, 0],cen[i, 1],color='cyan', s=400)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 plt.scatter(X, y_true, color='yellow', alpha=0.5, edgecolor='black')
#       2 for i in cen:
#       3     plt.scatter(cen[i, 0],cen[i, 1],color='cyan', s=400)
#
# File c:\Users\RAUL GLEZ\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2790, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2785 @_copy_docstring_and_deprecators(Axes.scatter)
#    2786 def scatter(
#    2787         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2788         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2789         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2790     __ret = gca().scatter(
#    2791         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...
